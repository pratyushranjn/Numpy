# %% [markdown]
# ## Advance operation with examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurantId, 2021, 2022, 2023, 2024]
sales_data = np.array(
    [
        [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
        [2, 120000, 140000, 160000, 190000],  # Beijing Bites
        [3, 200000, 230000, 260000, 300000],  # Pizza Hub
        [4, 180000, 210000, 240000, 270000],  # Burger Point
        [5, 160000, 185000, 205000, 230000],  # Chai Point
    ]
)

print("==== Zomato sales analysis ==== ")
print("\n Sales data shape", sales_data.shape)
print("First 3 restaurant data:\n", sales_data[0:3])
# Out:
# ==== Zomato sales analysis ====
#
#  Sales data shape (5, 5)
# First 3 restaurant data:
#  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
# Total sales per year (exclude first column)
# yearly_total = np.sum(sales_data[:, 1:], axis=0)
# print("\nTotal Sales Per Year (2021-2024):")
# print("2021 →", yearly_total[0])
# print("2022 →", yearly_total[1])
# print("2023 →", yearly_total[2])
# print("2024 →", yearly_total[3])


# Minimum sales per restaurant
min_sales = np.min(sales_data[:, 1:], axis=1)  # X axis
print(f"\nOverall Minimum Sale: {min_sales}")

# 🔼 Maximum sales per year
max_sale = np.max(sales_data[:, 1:], axis=0)
print("Maximum Sales Per Year (2021–2024):", max_sale)

# 📊 Average sales per restaurant
average_sales = np.mean(sales_data[:, 1:], axis=1)
print("Average Sales Per Restaurant:", average_sales)
# Out:
# Overall Minimum Sale: [150000 120000 200000 180000 160000]
# Maximum Sales Per Year (2021–2024): [200000 230000 260000 300000]
# Average Sales Per Restaurant: [200000. 152500. 247500. 225000. 195000.]

# %%
cumulative_sum = np.cumsum(sales_data[:, 1:], axis=1)
print(cumulative_sum)

plt.figure(figsize=(8, 6))
plt.plot(np.mean(cumulative_sum, axis=0))
plt.title("Average cumulative sales across all restaurant")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
vector1 = np.array([1, 2, 3, 4, 5])
vector2 = np.array([6, 7, 8, 9, 10])

print("Vector addititon ", vector1 + vector2)

print("\nMultiplication vector ", vector1 * vector2)
print("\nDot Product:", np.dot(vector1, vector2))

angle = np.arccos(
    np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2))
)

print(angle)
# Out:
# Vector addititon  [ 7  9 11 13 15]
#
# Multiplication vector  [ 6 14 24 36 50]
#
# Dot Product: 130
# 0.26554161733900966

# %%
restaurant_types = np.array(['biryani', 'chai', 'pizza', 'samosa'])

# vectorized operation
vectorized_upper = np.vectorize(str.upper)

print('Vectorized Upper:\n', vectorized_upper(restaurant_types))
# Out:
# Vectorized Upper:
#  ['BIRYANI' 'CHAI' 'PIZZA' 'SAMOSA']

# %% [markdown]
# ## Broadcasting

# %%
monthly_avg = sales_data[:, 1:] / 12

print(monthly_avg)
# Out:
# [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
